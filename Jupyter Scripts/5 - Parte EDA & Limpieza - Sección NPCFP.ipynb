# %% [markdown]
# # Análisis de la Encuesta Multiproposito

# %% [markdown]
# ## Importación de Paquetes y carga del archivo

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %%
data = pd.read_excel('Encuesta_Multiproposito_Suba.xlsx')

# %%
data.shape
# Out:
# (24536, 498)

# %% [markdown]
# **Hay en total 24536 encuestados en la Localidad de Suba**

# %% [markdown]
# # Quinta Sección (NPCFP)

# %% [markdown]
# ## NPCFP1
# ### 1. ¿... está afiliado/a (cotizante o beneficiario/a)  a alguna entidad de seguridad social en salud?
# (Entidad  Promotora de Salud (EPS), Entidad Promotora de Salud del régimen Subsidiado (EPS-S), entidades de regímenes de excepción o especial)
#
# - 0. No
# - 1. Sí
# - 9. No sabe, no informa
#
# **Datos: 24536**

# %%
data['NPCFP1'].count()
# Out:
# 24536

# %%
data['NPCFP1'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.01
# std          0.71
# min          0.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          9.00
# Name: NPCFP1, dtype: object

# %%
data = data.replace({'NPCFP1':{2:0}})

# %%
data['NPCFP1'].value_counts()
# Out:
# 1    23271
# 0     1087
# 9      178
# Name: NPCFP1, dtype: int64

# %%
data['NPCFP1'] = data['NPCFP1'].replace([0,1,9],["No","Si","No sabe, no informa"])

# %%
fig, ax = plt.subplots(figsize=(10, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP1')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('Pregunta NPCFP1 \n ¿... está afiliado/a (cotizante o beneficiario/a) a alguna entidad de seguridad social en salud? \n (Entidad Promotora de Salud (EPS), Entidad Promotora de Salud del régimen Subsidiado (EPS-S), entidades de regímenes de excepción o especial)')
#ax.set_xticklabels(['No','Si','No sabe, no responde'])

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP3
# ### 3. ¿Por qué razón principal no está afiliado/a?
# 1. Falta de dinero
# 2. Muchos trámites
# 3. No le interesa o descuido
# 4. No sabe que debe afiliarse o cómo afiliarse
# 5. No está vinculado/a laboralmente a una empresa o entidad
# 6. No tiene el puntaje requerido para acceder al régimen subsidiado
# 7. Por ser extranjero/a
# 8. Está en tramite de afiliación
# 9. Otra razón
#
# **Datos: 1087**

# %%
data['NPCFP3'].count()
# Out:
# 1087

# %%
data['NPCFP3'].describe().apply("{0:.2f}".format)
# Out:
# count    1087.00
# mean        4.66
# std         2.66
# min         1.00
# 25%         1.00
# 50%         5.00
# 75%         7.00
# max         9.00
# Name: NPCFP3, dtype: object

# %%
data['NPCFP3'].value_counts()
# Out:
# Falta de dinero                                                      309
# Por ser extranjero/a                                                 308
# No está vinculado/a laboralmente a una empresa o entidad             234
# Está en tramite de afiliación                                         81
# No tiene el puntaje requerido  para acceder al régimen subsidiado     44
# No le interesa o descuido                                             37
# Otra razón                                                            31
# Muchos trámites                                                       23
# No sabe que debe afiliarse o cómo afiliarse                           20
# Name: NPCFP3, dtype: int64

# %%
data['NPCFP3'] = data['NPCFP3'].replace([1,2,3,4,5,6,7,8,9],['Falta de dinero','Muchos trámites','No le interesa o descuido',
                    'No sabe que debe afiliarse o cómo afiliarse',
                    'No está vinculado/a laboralmente a una empresa o entidad',
                    'No tiene el puntaje requerido  para acceder al régimen subsidiado',
                    'Por ser extranjero/a','Está en tramite de afiliación','Otra razón'])

# %%
fig, ax = plt.subplots(figsize=(18, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP3')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('Pregunta NPCFP3 \n ¿Por qué razón principal no está afiliado/a?')
#ax.set_xticklabels(fontsize=7)

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP7
# ### 6. ¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas por la entidad de seguridad social en salud a la que está afiliado/a?
#
# 0. No
# 1. Si
#
# **Datos: 23126**

# %%
data['NPCFP7'].count()
# Out:
# 23126

# %%
data['NPCFP7'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean         0.07
# std          0.26
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          0.00
# max          1.00
# Name: NPCFP7, dtype: object

# %%
data = data.replace({'NPCFP7':2},0)

# %%
data['NPCFP7'].value_counts()
# Out:
# 0.0    21478
# 1.0     1648
# Name: NPCFP7, dtype: int64

# %%
data['NPCFP7'] = data['NPCFP7'].replace([0,1],["No","Si"])

# %%
fig, ax = plt.subplots(figsize=(10, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP7')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('Pregunta NPCFP7 \n ¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas \n por la entidad de seguridad social en salud a la que está afiliado/a?')
#ax.set_xticklabels(['No','Si'])

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP7{A1-A4}
# ### 6a. ¿… en los ÚLTIMOS 12 MESES ha participado en acciones preventivas realizadas por la entidad de seguridad social en salud a la que está afiliado/a, tales como:
# **Datos: 4252**

# %%
salud_i = [i for i in data.columns if 'NPCFP7A' in str(i)]

# %%
salud_i
# Out:
# ['NPCFP7A1', 'NPCFP7A2', 'NPCFP7A3', 'NPCFP7A4']

# %%
for i in salud_i:
    print(i, data[i].count())
# Out:
# NPCFP7A1 4252
# NPCFP7A2 4252
# NPCFP7A3 4252
# NPCFP7A4 4432

# %%
l_salud = ['Desparasitación','Vacunación','Enseñanza de cepillado y aplicación de fluor o sellantes','Anticoncepción y prevención de enfermedades de transmisión sexual']

# %%
for i in salud_i:
    data = data.replace({i:2},0)

# %%
for i in salud_i:
    data[i] = data[i].replace([0,1],["No","Si"])

# %%
fig, axes = plt.subplots(1,2, figsize = (15,4))
fig.subplots_adjust(top=0.9)
fig.suptitle('¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas \n por la entidad de seguridad social en salud a la que está afiliado/a?')
for ax,cols,names in zip(axes,salud_i,l_salud):
    sns.countplot(x = cols, data = data, ax = ax)
    ax.grid(alpha = 0.2, axis = 'y')
    ax.set_title(f'{names}')
    #ax.set_xticklabels(['No','Si'])
    ax.set_ylim(0,4000)
    ax.margins(y=0.1) # make room for the labels
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%.0f', fontsize=9)
plt.tight_layout()
    
fig, axes = plt.subplots(1,2, figsize = (15,4))
for ax,cols,names in zip(axes,salud_i[2:],l_salud[2:]):
    sns.countplot(x = cols, data = data, ax = ax)
    ax.grid(alpha = 0.2, axis = 'y')
    ax.set_title(f'{names}')
    #ax.set_xticklabels(['No','Si'])
    ax.set_ylim(0,4000)
    ax.margins(y=0.1) # make room for the labels
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%.0f', fontsize=9)
plt.tight_layout()

    
plt.show()

# %% [markdown]
# ## NPCFP8
# ### 7. En general, considera que la calidad del servicio de la entidad de seguridad social en salud a la que ...está afiliado(a) es:
#
# 1. Muy buena
# 2. Buena
# 3. Regular
# 4. Mala
# 5. Muy mala
# 6. No sabe, no informa
#
# **Datos: 23126**

# %%
data['NPCFP8'].count()
# Out:
# 23126

# %%
data['NPCFP8'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean         2.11
# std          1.13
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          9.00
# Name: NPCFP8, dtype: object

# %%
data['NPCFP8'].value_counts()
# Out:
# 2.0    16854
# 1.0     3537
# 3.0     1783
# 9.0      447
# 4.0      346
# 5.0      159
# Name: NPCFP8, dtype: int64

# %%
data['NPCFP8'] = data['NPCFP8'].replace([1,2,3,4,5,9],['Muy buena','Buena','Regular','Mala','Muy mala','No sabe, no informa'])

# %%
data['NPCFP8'].value_counts()
# Out:
# Buena                  16854
# Muy buena               3537
# Regular                 1783
# No sabe, no informa      447
# Mala                     346
# Muy mala                 159
# Name: NPCFP8, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP8')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('Pregunta NPCFP8 \n En general, considera que la calidad del servicio de la entidad de seguridad social en salud a la que ...está afiliado(a) es')
#ax.set_xticklabels(['Muy buena','Buena','Regular','Mala','Muy mala','No sabe,\n no informa'])

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP9
# ### 10. En promedio, ¿cuánto tiempo se demora en llegar ...desde su lugar de residencia a la IPS para sus consultas de medicina general? Minutos
#
# **Datos: 23126**
#
# *Revisar caso de 1000*

# %%
data['NPCFP9'].count()
# Out:
# 23126

# %%
data['NPCFP9'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean        32.71
# std         18.71
# min          1.00
# 25%         20.00
# 50%         30.00
# 75%         40.00
# max        420.00
# Name: NPCFP9, dtype: object

# %%
data['NPCFP9'] = data['NPCFP9'].replace(999,stats.trim_mean(data['NPCFP9'],0.1))

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,1,1)
counts, edges, bars = plt.hist(data['NPCFP9'] , edgecolor = 'black', color = '#ef233c')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(9))
#plt.xticks(np.linspace(0, data['NPCEP8A'].max(),6),rotation = 45)
#plt.bar_label(bars)
plt.title('Pregunta NPCFP9 \n En promedio, ¿cuánto tiempo se demora en llegar ...desde su lugar de residencia a la IPS para sus consultas de medicina general? Minutos')
#plt.xlim([-1,10])
plt.axvline(data['NPCFP9'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NPCFP9"].mean()}')
plt.axvline(data['NPCFP9'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NPCFP9"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP13{A-F}
# ### 14. Sin estar enfermo/a y por prevención, ¿… por lo menos una vez al AÑO, consulta?
#
# **Datos: 24536**

# %%
consulta = [i for i in data.columns if 'NPCFP13' in str(i)]

# %%
consulta
# Out:
# ['NPCFP13A', 'NPCFP13B', 'NPCFP13C', 'NPCFP13D', 'NPCFP13F']

# %%
for i in consulta:
    print(i, data[i].count())
# Out:
# NPCFP13A 24536
# NPCFP13B 24536
# NPCFP13C 24536
# NPCFP13D 24536
# NPCFP13F 24536

# %%
l_consulta = ['Médicina General',
              'Medicina Especializada',
              'Odontologia',
              'Medicina Alternativa',
             'Psicología']

# %%
for i in consulta:
    data = data.replace({i:2},0)

# %%
for i in consulta:
    data[i] = data[i].replace([0,1],["No","Si"])

# %%
fig, axes = plt.subplots(1,2, figsize = (15,4))
fig.subplots_adjust(top=0.9)
fig.suptitle('Sin estar enfermo/a y por prevención, ¿… por lo menos una vez al AÑO, consulta?')
for ax,cols,names in zip(axes,consulta,l_consulta):
    sns.countplot(x = cols, data = data, ax = ax)
    ax.grid(alpha = 0.2, axis = 'y')
    ax.set_title(f'{names}')
    #ax.set_xticklabels(['No','Si'])
    ax.set_ylim(0,25000)
    ax.margins(y=0.1) # make room for the labels
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%.0f', fontsize=9)
plt.tight_layout()
    
fig, axes = plt.subplots(1,2, figsize = (15,4))
for ax,cols,names in zip(axes,consulta[2:],l_consulta[2:]):
    sns.countplot(x = cols, data = data, ax = ax)
    ax.grid(alpha = 0.2, axis = 'y')
    ax.set_title(f'{names}')
    #ax.set_xticklabels(['No','Si'])
    ax.set_ylim(0,25000)
    ax.margins(y=0.1) # make room for the labels
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%.0f', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## NPCFP14C
# ### 15. ¿A ...le han diagnosticado alguna de estas enfermedades o problemas de salud: Enfermedades mentales o del comportamiento   (depresión, ansiedad, esquizofrenia, trastorno bipolar, alzheimer)?
#
# **Datos: 24536**

# %%
data['NPCFP14C'].count()
# Out:
# 24536

# %%
data['NPCFP14C'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         0.02
# std          0.14
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          0.00
# max          1.00
# Name: NPCFP14C, dtype: object

# %%
data = data.replace({'NPCFP14C':2},0)

# %%
data['NPCFP14C'].value_counts()
# Out:
# 0    24024
# 1      512
# Name: NPCFP14C, dtype: int64

# %%
data['NPCFP14C'] = data['NPCFP14C'].replace([0,1],["No","Si"])

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP14C'].value_counts().index.tolist(),data['NPCFP14C'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
#plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NPCFP14C \n ¿A ...le han diagnosticado alguna de estas enfermedades o problemas de salud: \n Enfermedades mentales o del comportamiento (depresión, ansiedad, esquizofrenia, trastorno bipolar, alzheimer)?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP24
# ### 23. ¿Quién se ocupa principalmente del cuidado de ...?
# 1. Una persona de este hogar, no remunerada
# 2. Una persona de otro hogar, no remunerada
# 3. Una persona contratada para ayudarle
# 4. Una institución
#
# **Datos: 735**

# %%
data['NPCFP24'].count()
# Out:
# 735

# %%
data['NPCFP24'].describe().apply("{0:.2f}".format)
# Out:
# count    735.00
# mean       1.38
# std        0.74
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        1.00
# max        4.00
# Name: NPCFP24, dtype: object

# %%
data['NPCFP24'].value_counts()
# Out:
# 1.0    565
# 3.0     97
# 2.0     67
# 4.0      6
# Name: NPCFP24, dtype: int64

# %%
data['NPCFP24'] = data['NPCFP24'].replace([1,2,3,4],['Una persona de este hogar, no remunerada','Una persona de otro hogar, no remunerada',
                    'Una persona contratada para ayudarle','Una institución'])

# %%
fig, ax = plt.subplots(figsize=(18, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP24')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('Pregunta NPCFP24 \n ¿Quién se ocupa principalmente del cuidado de ...?')
#ax.set_xticklabels(['Una persona de \n este hogar, no remunerada','Una persona de \n otro hogar, no remunerada',
#                    'Una persona contratada \n para ayudarle','Una institución'])

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP24A
#
# ### 23a. Una persona de este hogar, no remunerada. Núm. de orden
#
# **Datos: 565**

# %%
data['NPCFP24A'].count()
# Out:
# 565

# %%
data['NPCFP24A'].describe().apply("{0:.2f}".format)
# Out:
# count    565.00
# mean       1.68
# std        0.91
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        2.00
# max        7.00
# Name: NPCFP24A, dtype: object

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
counts, edges, bars = plt.hist(data['NPCFP24A'] , bins = np.arange(1,9) - 0.5, edgecolor = 'black', color = '#ef233c')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(9))
#plt.xticks(np.linspace(0, data['NPCEP8A'].max(),6),rotation = 45)
plt.bar_label(bars)
plt.title('Pregunta NPCFP24A \n Una persona de este hogar, no remunerada Núm. de orden')
#plt.xlim([-1,10])
plt.axvline(data['NPCFP24A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NPCFP24A"].mean()}')
plt.axvline(data['NPCFP24A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NPCFP24A"].median()}')
plt.legend()
plt.ylim((0,400))
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP24B
#
# ### 23b. Una persona de otro hogar no remunerada, o, una persona contratada, esta persona es:
#
# 1. Hombre
# 2. Mujer
#
# **Solo contestan 164**

# %%
data['NPCFP24B'].count()
# Out:
# 164

# %%
data['NPCFP24B'].describe().apply("{0:.2f}".format)
# Out:
# count    164.00
# mean       1.92
# std        0.27
# min        1.00
# 25%        2.00
# 50%        2.00
# 75%        2.00
# max        2.00
# Name: NPCFP24B, dtype: object

# %%
data['NPCFP24B'].value_counts()
# Out:
# 2.0    151
# 1.0     13
# Name: NPCFP24B, dtype: int64

# %%
data['NPCFP24B'] = data['NPCFP24B'].replace([1,2], ['Hombre', 'Mujer'])

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP24B'].value_counts().index.tolist(),data['NPCFP24B'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
#plt.xticks([1,2], ['Hombre', 'Mujer'])
plt.title('Pregunta NPCFP14C \n Una persona de otro hogar no remunerada, o, una persona contratada, esta persona es:')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP33G
#
# ### 31.Durante los ÚLTIMOS 30 DÍAS, ...utilizó servicios de salud para: Servicios de psicología o psiquiatria?
#
# 1. Sí
# 2. No
#
# **Datos: 24536**

# %%
data['NPCFP33G'].count()
# Out:
# 24536

# %%
data['NPCFP33G'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         0.02
# std          0.14
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          0.00
# max          1.00
# Name: NPCFP33G, dtype: object

# %%
data = data.replace({'NPCFP33G':2},0)

# %%
data['NPCFP33G'].value_counts()
# Out:
# 0    24027
# 1      509
# Name: NPCFP33G, dtype: int64

# %%
data['NPCFP33G'] = data['NPCFP33G'].replace([0,1], ['No','Si'])

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP33G'].value_counts().index.tolist(),data['NPCFP33G'].value_counts().tolist(), edgecolor = 'k', color = '#f4a261')
#plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NPCFP33G \n Durante los ÚLTIMOS 30 DÍAS, ...utilizó servicios de salud para: \n Servicios de psicología o psiquiatria?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP36
#
# ### 34. En los ÚLTIMOS 30 DÍAS, ¿cuántas veces por semana ...practicó deporte o realizó actividad física por 30 minutos continuos o más?
#
# 1. 3 o más veces por semana
# 2. 1 a 2 veces por semana
# 3. Menos de una vez a la semana
# 4. No practicó deporte ni tuvo actividad física en el mes
#
# **Datos: 22213**

# %%
data['NPCFP36'].count()
# Out:
# 22213

# %%
data['NPCFP36'].value_counts()
# Out:
# 4.0    8387
# 1.0    6978
# 2.0    4796
# 3.0    2052
# Name: NPCFP36, dtype: int64

# %%
data['NPCFP36'] = data['NPCFP36'].replace([1,2,3,4], ['3 o más veces por semana',
'1 a 2 veces por semana',
'Menos de una vez a la semana',
'No practicó deporte ni tuvo actividad física en el mes'])

# %%
plt.figure(figsize=(18,5))
bars = plt.bar(data['NPCFP36'].value_counts().index.tolist(),data['NPCFP36'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
#plt.xticks([1,2,3,4], ['3 o más veces por semana',
#'1 a 2 veces por semana',
#'Menos de una vez a la semana',
#'No practicó deporte ni \n tuvo actividad física en el mes'])
plt.title('Pregunta NPCFP36 \n En los ÚLTIMOS 30 DÍAS, ¿cuántas veces por semana ...practicó deporte o realizó actividad física por 30 minutos continuos o más?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ## NPCFP37
# ### 35. ¿Cuál fue la razón principal para que ...no practicara deporte ni tuviera actividad física en los ÚLTIMOS 30 DÍAS?
# 1. Su salud no se lo permite
# 2. No le interesa o no le motiva
# 3. No tuvo tiempo
# 4. No tiene lugares donde hacerlo
# 5. No le alcanza el dinero para hacerlo
# 6. Otra razón
#
# **Datos: 8387**

# %%
data['NPCFP37'].count()
# Out:
# 8387

# %%
data['NPCFP37'].value_counts()
# Out:
# 3.0    3514
# 2.0    2721
# 1.0    1668
# 6.0     266
# 4.0     187
# 5.0      31
# Name: NPCFP37, dtype: int64

# %%
data['NPCFP37'] = data['NPCFP37'].replace([1,2,3,4,5,6],['Su salud no se lo permite', 'No le interesa o no le motiva','No tuvo tiempo',
                    'No tiene lugares donde hacerlo','No le alcanza el dinero para hacerlo', 'Otra razón'])

# %%
data['NPCFP37'].describe().apply("{0:.2f}".format)
# Out:
# count    8387.00
# mean        2.40
# std         1.04
# min         1.00
# 25%         2.00
# 50%         2.00
# 75%         3.00
# max         6.00
# Name: NPCFP37, dtype: object

# %%
fig, ax = plt.subplots(figsize=(18, 5))

g = sns.countplot(ax=ax, data = data, x ='NPCFP37')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f', fontsize=9)
            
ax.set_title('¿Cuál fue la razón principal para que ...no practicara deporte ni tuviera actividad física en los ÚLTIMOS 30 DÍAS?')
#ax.set_xticklabels(['Su salud no se lo permite', 'No le interesa o no le motiva','No tuvo tiempo',
#                    'No tiene lugares donde hacerlo','No le alcanza el \ndinero para hacerlo', 'Otra razón'])

plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %%
data.to_excel('Encuesta_Multiproposito_Suba.xlsx', index = False)
