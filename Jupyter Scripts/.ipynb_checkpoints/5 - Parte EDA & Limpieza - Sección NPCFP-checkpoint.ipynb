# %% [markdown]
# # Análisis de la Encuesta Multiproposito

# %% [markdown]
# ## Importación de Paquetes y carga del archivo

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %%
data = pd.read_csv('Encuesta_Suba_Filtrado_Preguntas.csv', sep = ',')

# %%
data.shape
# Out:
# (24536, 419)

# %% [markdown]
# **Hay en total 24536 encuestados en la Localidad de Suba**

# %% [markdown]
# # Revisión de cada columna

# %% [markdown]
# ## Quinta Sección (NPCFP)

# %% [markdown]
# ### NPCFP1
# ¿... está afiliado/a (cotizante o beneficiario/a)  a alguna entidad de seguridad social en salud?
# (Entidad  Promotora de Salud (EPS), Entidad Promotora de Salud del régimen Subsidiado (EPS-S), entidades de regímenes de excepción o especial)
#
# 0. No
# 1. Sí
# 2. No sabe, no informa
#
# **Todos Contestan**

# %%
data['NPCFP1'].count()
# Out:
# 24536

# %%
data['NPCFP1'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.10
# std          0.71
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          9.00
# Name: NPCFP1, dtype: object

# %%
data['NPCFP1'] = data.apply(lambda x: 0 if (x['NPCFP1'] == 2) else (1 if x['NPCFP1']==1 else 2), axis = 1)

# %%
data['NPCFP1'].value_counts()
# Out:
# 1    23271
# 0     1087
# 2      178
# Name: NPCFP1, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP1'].value_counts().index.tolist(),data['NPCFP1'].value_counts().tolist(), edgecolor = 'k', color = '#e07a5f')
plt.xticks([0,1,2], ['No','Si','No sabe, no responde'])
plt.title('Pregunta NPCFP1 \n ¿... está afiliado/a (cotizante o beneficiario/a) a alguna entidad de seguridad social en salud? \n (Entidad Promotora de Salud (EPS), Entidad Promotora de Salud del régimen Subsidiado (EPS-S), entidades de regímenes de excepción o especial)')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP3
# ¿Por qué razón principal no está afiliado/a?
# 1. Falta de dinero
# 2. Muchos trámites
# 3. No le interesa o descuido
# 4. No sabe que debe afiliarse o cómo afiliarse
# 5. No está vinculado/a laboralmente a una empresa o entidad
# 6. No tiene el puntaje requerido para acceder al régimen subsidiado
# 7. Por ser extranjero/a
# 8. Está en tramite de afiliación
# 9. Otra razón
#
# **Solo contestan 1087**

# %%
data['NPCFP3'].count()
# Out:
# 1087

# %%
data['NPCFP3'].describe().apply("{0:.2f}".format)
# Out:
# count    1087.00
# mean        4.66
# std         2.66
# min         1.00
# 25%         1.00
# 50%         5.00
# 75%         7.00
# max         9.00
# Name: NPCFP3, dtype: object

# %%
data['NPCFP3'].value_counts()
# Out:
# 1.0    309
# 7.0    308
# 5.0    234
# 8.0     81
# 6.0     44
# 3.0     37
# 9.0     31
# 2.0     23
# 4.0     20
# Name: NPCFP3, dtype: int64

# %%
plt.figure(figsize=(18,5))
bars = plt.bar(data['NPCFP3'].value_counts().index.tolist(),data['NPCFP3'].value_counts().tolist(), edgecolor = 'k', color = '#f6bd60')
plt.xticks([1,2,3,4,5,6,7,8,9], ['Falta de dinero',
'Muchos trámites',
'No le interesa \n o descuido',
'No sabe que \n debe afiliarse \n o cómo afiliarse',
'No está vinculado/a \n laboralmente a una \n empresa o entidad',
'No tiene el \n puntaje requerido \n  para acceder al \n régimen subsidiado',
'Por ser extranjero/a',
'Está en tramite \n de afiliación',
'Otra razón'])
plt.title('Pregunta NPCFP3 \n ¿Por qué razón principal no está afiliado/a?')
plt.bar_label(bars, padding = 2)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP7
# ¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas por la entidad de seguridad social en salud a la que está afiliado/a?
#
# 0. No
# 1. Si
# 2. No contesta
#
# **Contestan 23126**

# %%
data['NPCFP7'].count()
# Out:
# 23126

# %%
data['NPCFP7'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean         1.93
# std          0.26
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NPCFP7, dtype: object

# %%
data['NPCFP7'] = data.apply(lambda x: 0 if (x['NPCFP7'] == 2) else (1 if x['NPCFP7']==1 else 2), axis = 1)

# %%
data['NPCFP7'].value_counts()
# Out:
# 0    21478
# 1     1648
# 2     1410
# Name: NPCFP7, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP7'].value_counts().index.tolist(),data['NPCFP7'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
plt.xticks([0,1,2], ['No','Si','No contesta'])
plt.title('Pregunta NPCFP7 \n ¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas \n por la entidad de seguridad social en salud a la que está afiliado/a?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NPCFP7___
#
# **Solo contestan 4252**

# %%
salud_i = [i for i in data.columns if 'NPCFP7A' in str(i)]

# %%
salud_i
# Out:
# ['NPCFP7A1', 'NPCFP7A2', 'NPCFP7A3', 'NPCFP7A4']

# %%
for i in salud_i:
    print(i, data[i].count())
# Out:
# NPCFP7A1 4252
# NPCFP7A2 4252
# NPCFP7A3 4252
# NPCFP7A4 4432

# %%
l_salud = ['Desparasitación','Vacunación','Enseñanza de cepillado y aplicación de fluor o sellantes','Anticoncepción y prevención de enfermedades de transmisión sexual']

# %%
for i in salud_i:
    data[i] = data.apply(lambda x: 0 if (x[i] == 2) else (1 if x[i]==1 else 2), axis = 1)

# %%
for i,j,z in zip(salud_i,l_salud,colors):
    plt.figure(figsize=(10,5))
    bars = plt.bar(data[i].value_counts().index.tolist(),data[i].value_counts().tolist(), edgecolor = 'black', color = z)
    plt.title(f'Pregunta {i} \n ¿… en los ÚLTIMOS 12 MESES ha participado en acciones informativas de cuidado personal, familiar o comunitario y del ambiente que promueven la salud, realizadas \n por la entidad de seguridad social en salud a la que está afiliado/a?\n {j}')
    plt.xticks([0,1,2],['No','Si','No Contesta'])
    plt.bar_label(bars)
    plt.show()

# %% [markdown]
# ### NPCFP8
# En general, considera que la calidad del servicio de la entidad de seguridad social en salud a la que ...está afiliado(a) es:
#
# 1. Muy buena
# 2. Buena
# 3. Regular
# 4. Mala
# 5. Muy mala
# 6. No sabe, no informa
#
# **Contestan 23126**

# %%
data['NPCFP8'].count()
# Out:
# 23126

# %%
data['NPCFP8'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean         2.11
# std          1.13
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          9.00
# Name: NPCFP8, dtype: object

# %%
data['NPCFP8'].value_counts()
# Out:
# 2.0    16854
# 1.0     3537
# 3.0     1783
# 9.0      447
# 4.0      346
# 5.0      159
# Name: NPCFP8, dtype: int64

# %%
data['NPCFP8'] = data.apply(lambda x: 2 if (x['NPCFP8'] == 2) else (1 if x['NPCFP8']==1 else (3 if x['NPCFP8']==3 else (4 if x['NPCFP8']==4 else (5 if x['NPCFP8']==5 else (6 if x['NPCFP8']==9 else 7))))), axis = 1)

# %%
data['NPCFP8'].value_counts()
# Out:
# 2    16854
# 1     3537
# 3     1783
# 7     1410
# 6      447
# 4      346
# 5      159
# Name: NPCFP8, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP8'].value_counts().index.tolist(),data['NPCFP8'].value_counts().tolist(), edgecolor = 'k', color = '#14213d')
plt.xticks([1,2,3,4,5,6,7], ['Muy buena',
'Buena',
'Regular',
'Mala',
'Muy mala',
'No sabe,\n no informa',
                            'No Contesta'])
plt.title('Pregunta NPCFP8 \n En general, considera que la calidad del servicio de la entidad de seguridad social en salud a la que ...está afiliado(a) es')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP9
# En promedio, ¿cuánto tiempo se demora en llegar ...desde su lugar de residencia a la IPS para sus consultas de medicina general?
# Minutos
#
# **Contestan 23126**

# %%
data['NPCFP9'].count()
# Out:
# 23126

# %%
data['NPCFP9'].describe().apply("{0:.2f}".format)
# Out:
# count    23126.00
# mean        71.45
# std        190.68
# min          1.00
# 25%         20.00
# 50%         30.00
# 75%         40.00
# max        999.00
# Name: NPCFP9, dtype: object

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
counts, edges, bars = plt.hist(data['NPCFP9'] , bins = 100, edgecolor = 'black', color = '#ef233c')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(9))
#plt.xticks(np.linspace(0, data['NPCEP8A'].max(),6),rotation = 45)
#plt.bar_label(bars)
plt.title('Pregunta NPCFP9 \n En promedio, ¿cuánto tiempo se demora en llegar ...desde su lugar de residencia a la IPS para sus consultas de medicina general? Minutos')
#plt.xlim([-1,10])
plt.axvline(data['NPCFP9'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NPCFP9"].mean()}')
plt.axvline(data['NPCFP9'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NPCFP9"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.subplot(2,1,2)
counts, edges, bars = plt.hist(data['NPCFP9'] , bins = np.arange(100) - 0.5, edgecolor = 'black', color = '#ef233c')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(9))
#plt.xticks(np.linspace(0, data['NPCEP8A'].max(),6),rotation = 45)
#plt.bar_label(bars)
#plt.xlim([-1,10])
plt.axvline(stats.trim_mean(data['NPCFP9'], 0.125), color='k', linestyle=':', linewidth=1, label = f'Trim Mean = {stats.trim_mean(data["NPCFP9"], 0.125)}')
plt.axvline(data['NPCFP9'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NPCFP9"].median()}')
plt.xticks(range(0,101,5))
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP13_
# Sin estar enfermo/a y por prevención, ¿… por lo menos una vez al AÑO, consulta?
#
# **Todos Contestan**

# %%
consulta = [i for i in data.columns if 'NPCFP13' in str(i)]

# %%
consulta
# Out:
# ['NPCFP13A', 'NPCFP13B', 'NPCFP13C', 'NPCFP13D', 'NPCFP13F']

# %%
for i in consulta:
    print(i, data[i].count())
# Out:
# NPCFP13A 24536
# NPCFP13B 24536
# NPCFP13C 24536
# NPCFP13D 24536
# NPCFP13F 24536

# %%
l_consulta = ['Médicina General',
              'Medicina Especializada',
              'Odontologia',
              'Medicina Alternativa',
             'Psicología']

# %%
for i in consulta:
    data[i] = data.apply(lambda x: 0 if (x[i] == 2) else (1 if x[i]==1 else 2), axis = 1)

# %%
for i,j,z in zip(consulta,l_consulta,colors):
    plt.figure(figsize=(10,5))
    bars = plt.bar(data[i].value_counts().index.tolist(),data[i].value_counts().tolist(), edgecolor = 'black', color = z)
    plt.title(f'Pregunta {i} \n Sin estar enfermo/a y por prevención, ¿… por lo menos una vez al AÑO, consulta?\n {j}')
    plt.xticks([0,1],['No','Si'])
    plt.bar_label(bars)
    plt.show()

# %% [markdown]
# ### NPCFP14C
# ¿A ...le han diagnosticado alguna de estas enfermedades o problemas de salud:
#
# Enfermedades mentales o del comportamiento   (depresión, ansiedad, esquizofrenia, trastorno bipolar, alzheimer)?
#
# **Todos Contestan**

# %%
data['NPCFP14C'].count()
# Out:
# 24536

# %%
data['NPCFP14C'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.98
# std          0.14
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NPCFP14C, dtype: object

# %%
data['NPCFP14C'] = data.apply(lambda x: 0 if (x['NPCFP14C'] == 2) else (1 if x['NPCFP14C']==1 else 2), axis = 1)

# %%
data['NPCFP14C'].value_counts()
# Out:
# 0    24024
# 1      512
# Name: NPCFP14C, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP14C'].value_counts().index.tolist(),data['NPCFP14C'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NPCFP14C \n ¿A ...le han diagnosticado alguna de estas enfermedades o problemas de salud: \n Enfermedades mentales o del comportamiento (depresión, ansiedad, esquizofrenia, trastorno bipolar, alzheimer)?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP24
# ¿Quién se ocupa principalmente del cuidado de ...?
# 1. Una persona de este hogar, no remunerada
# 2. Una persona de otro hogar, no remunerada
# 3. Una persona contratada para ayudarle
# 4. Una institución
#
# **Contestan 735**

# %%
data['NPCFP24'].count()
# Out:
# 735

# %%
data['NPCFP24'].describe().apply("{0:.2f}".format)
# Out:
# count    735.00
# mean       1.38
# std        0.74
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        1.00
# max        4.00
# Name: NPCFP24, dtype: object

# %%
data['NPCFP24'].value_counts()
# Out:
# 1.0    565
# 3.0     97
# 2.0     67
# 4.0      6
# Name: NPCFP24, dtype: int64

# %%
data['NPCFP24'] = data.apply(lambda x: 2 if (x['NPCFP24'] == 2) else (1 if x['NPCFP24']==1 else (3 if x['NPCFP24']==3 else (4 if x['NPCFP24']==4 else 5))), axis = 1)

# %%
data['NPCFP24'].value_counts()
# Out:
# 5    23801
# 1      565
# 3       97
# 2       67
# 4        6
# Name: NPCFP24, dtype: int64

# %%
plt.figure(figsize=(18,5))
bars = plt.bar(data['NPCFP24'].value_counts().index.tolist(),data['NPCFP24'].value_counts().tolist(), edgecolor = 'k', color = '#14213d')
plt.xticks([1,2,3,4,5], ['Una persona de \n este hogar, no remunerada',
'Una persona de \n otro hogar, no remunerada',
'Una persona contratada \n para ayudarle',
'Una institución',
                        'No Contesta'])
plt.title('Pregunta NPCFP24 \n ¿Quién se ocupa principalmente del cuidado de ...?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NPCFP24A
#
# Una persona de este hogar, no remunerada
#
# Núm. de orden
#
# **Contestan 565**

# %%
data['NPCFP24A'].count()
# Out:
# 565

# %%
data['NPCFP24A'].describe().apply("{0:.2f}".format)
# Out:
# count    565.00
# mean       1.68
# std        0.91
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        2.00
# max        7.00
# Name: NPCFP24A, dtype: object

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
counts, edges, bars = plt.hist(data['NPCFP24A'] , bins = np.arange(1,9) - 0.5, edgecolor = 'black', color = '#ef233c')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(9))
#plt.xticks(np.linspace(0, data['NPCEP8A'].max(),6),rotation = 45)
plt.bar_label(bars)
plt.title('Pregunta NPCFP24A \n Una persona de este hogar, no remunerada Núm. de orden')
#plt.xlim([-1,10])
plt.axvline(data['NPCFP24A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NPCFP24A"].mean()}')
plt.axvline(data['NPCFP24A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NPCFP24A"].median()}')
plt.legend()
plt.ylim((0,400))
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NPCFP24B
#
# Una persona de otro hogar no remunerada, o, una persona contratada, esta persona es:
#
# 1. Hombre
# 2. Mujer
#
# **Solo contestan 164**

# %%
data['NPCFP24B'].count()
# Out:
# 164

# %%
data['NPCFP24B'].describe().apply("{0:.2f}".format)
# Out:
# count    164.00
# mean       1.92
# std        0.27
# min        1.00
# 25%        2.00
# 50%        2.00
# 75%        2.00
# max        2.00
# Name: NPCFP24B, dtype: object

# %%
data['NPCFP24B'] = data.apply(lambda x: 2 if (x['NPCFP24B'] == 2) else (1 if x['NPCFP24B']==1 else 0), axis = 1)

# %%
data['NPCFP24B'].value_counts()
# Out:
# 0    24372
# 2      151
# 1       13
# Name: NPCFP24B, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP24B'].value_counts().index.tolist(),data['NPCFP24B'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
plt.xticks([0,1,2], ['No Contesta','Hombre', 'Mujer'])
plt.title('Pregunta NPCFP14C \n Una persona de otro hogar no remunerada, o, una persona contratada, esta persona es:')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP33G
#
# Durante los ÚLTIMOS 30 DÍAS, ...utilizó servicios de salud para:
#
# Servicios de psicología o psiquiatria?
#
# 1. Sí
# 2. No
#
# **Todos Contestan**

# %%
data['NPCFP33G'].count()
# Out:
# 24536

# %%
data['NPCFP33G'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.98
# std          0.14
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NPCFP33G, dtype: object

# %%
data['NPCFP33G'] = data.apply(lambda x: 0 if (x['NPCFP33G'] == 2) else (1 if x['NPCFP33G']==1 else 2), axis = 1)

# %%
data['NPCFP33G'].value_counts()
# Out:
# 0    24027
# 1      509
# Name: NPCFP33G, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NPCFP33G'].value_counts().index.tolist(),data['NPCFP33G'].value_counts().tolist(), edgecolor = 'k', color = '#f4a261')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NPCFP33G \n Durante los ÚLTIMOS 30 DÍAS, ...utilizó servicios de salud para: \n Servicios de psicología o psiquiatria?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NPCFP36
#
# En los ÚLTIMOS 30 DÍAS, ¿cuántas veces por semana ...practicó deporte o realizó actividad física por 30 minutos continuos o más?
#
# 1. 3 o más veces por semana
# 2. 1 a 2 veces por semana
# 3. Menos de una vez a la semana
# 4. No practicó deporte ni tuvo actividad física en el mes
#
# **Solo contestan 22213**

# %%
data['NPCFP36'].count()
# Out:
# 22213

# %%
data['NPCFP36'].value_counts()
# Out:
# 4.0    8387
# 1.0    6978
# 2.0    4796
# 3.0    2052
# Name: NPCFP36, dtype: int64

# %%
data['NPCFP36'].describe().apply("{0:.2f}".format)
# Out:
# count    22213.00
# mean         2.53
# std          1.28
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          4.00
# max          4.00
# Name: NPCFP36, dtype: object

# %%
data['NPCFP36'] = data.apply(lambda x: 2 if (x['NPCFP36'] == 2) else (1 if x['NPCFP36']==1 else (3 if x['NPCFP36']==3 else (4 if x['NPCFP36']==4 else 0))), axis = 1)

# %%
data['NPCFP36'].value_counts()
# Out:
# 4    8387
# 1    6978
# 2    4796
# 0    2323
# 3    2052
# Name: NPCFP36, dtype: int64

# %%
plt.figure(figsize=(18,5))
bars = plt.bar(data['NPCFP36'].value_counts().index.tolist(),data['NPCFP36'].value_counts().tolist(), edgecolor = 'k', color = '#f4f1de')
plt.xticks([0,1,2,3,4], ['No Contesta','3 o más veces por semana',
'1 a 2 veces por semana',
'Menos de una vez a la semana',
'No practicó deporte ni \n tuvo actividad física en el mes'])
plt.title('Pregunta NPCFP36 \n En los ÚLTIMOS 30 DÍAS, ¿cuántas veces por semana ...practicó deporte o realizó actividad física por 30 minutos continuos o más?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()
