# %% [markdown]
# # Análisis de la Encuesta Multiproposito

# %% [markdown]
# ## Importación de Paquetes y carga del archivo

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %%
data = pd.read_csv('Encuesta_Suba_Filtrado_Preguntas.csv', sep = ',')

# %%
data.shape
# Out:
# (24536, 419)

# %% [markdown]
# **Hay en total 24536 encuestados en la Localidad de Suba**

# %% [markdown]
# # Revisión de cada columna

# %% [markdown]
# ## Tercera Sección (NHCDP)

# %% [markdown]
# ### NHCDP2
# ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de acueducto?
#
# **Contestaron 22998**

# %%
data['NHCDP2'].count()
# Out:
# 22998

# %%
data['NHCDP2'].describe().apply("{0:.2f}".format)
# Out:
# count      22998.00
# mean      134934.24
# std       140688.75
# min            0.00
# 25%        60000.00
# 50%       107238.00
# 75%       180000.00
# max      3000000.00
# Name: NHCDP2, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP2'], bins = 50, edgecolor = 'black', color = '#e9edc9')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(9))
#plt.bar_label(bars)
plt.title('NHCDP2 \n ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de acueducto?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP2'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP2"].mean()}')
plt.axvline(data['NHCDP2'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP2"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP11
# ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de energía eléctrica?
#
# **Contestaron 23186**

# %%
data['NHCDP11'].count()
# Out:
# 23186

# %%
data['NHCDP11'].describe().apply("{0:.2f}".format)
# Out:
# count      23186.00
# mean       99354.13
# std       120412.43
# min            0.00
# 25%        45744.00
# 50%        80000.00
# 75%       120000.00
# max      2680000.00
# Name: NHCDP11, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP11'], bins = 50, edgecolor = 'black', color = '#dda15e')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(9))
#plt.bar_label(bars)
plt.title('NHCDP11 \n¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de energía eléctrica?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP11'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP11"].mean()}')
plt.axvline(data['NHCDP11'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP11"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP11A
# ¿A cuántos meses correspondió el pago? (energía)
#
# **Contestaron 20607**

# %%
data['NHCDP11A'].count()
# Out:
# 20607

# %%
data['NHCDP11A'].describe().apply("{0:.2f}".format)
# Out:
# count    20607.00
# mean         1.01
# std          0.22
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max         12.00
# Name: NHCDP11A, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP11A'], bins = np.arange(14)-0.5 , edgecolor = 'black', color = '#a8dadc')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(9))
plt.bar_label(bars)
plt.title('NHCDP11A \n ¿A cuántos meses correspondió el pago? (energía)')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP11A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP11A"].mean()}')
plt.axvline(data['NHCDP11A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP11A"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP12
# ¿El valor pagado incluyó consumo por negocios de industria, comercio o servicios? (energía)
#
# 0. No
# 1. Si
# 2. No contesta
#
# **Contestaron 23186**

# %%
data['NHCDP12'].count()
# Out:
# 23186

# %%
data['NHCDP12'].describe().apply("{0:.2f}".format)
# Out:
# count    23186.00
# mean         1.97
# std          0.16
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP12, dtype: object

# %%
data['NHCDP12'] = data.apply(lambda x: 0 if (x['NHCDP12'] == 2) else (1 if x['NHCDP12']==1 else 2), axis = 1)

# %%
data['NHCDP12'].value_counts()
# Out:
# 0    22606
# 2     1350
# 1      580
# Name: NHCDP12, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP12'].value_counts().index.tolist(),data['NHCDP12'].value_counts().tolist(), edgecolor = 'black', color = '#e63946')
plt.xticks([0,1,2], ['No','Si','No Contesta'])
plt.title('Pregunta NHCDP12 \n ¿El valor pagado incluyó consumo por negocios de industria, comercio o servicios? (energía)')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP15
# ¿Este hogar tiene servicio de gas natural conectado a red pública?
#
# 0. No
# 1. Si
# 2. No contesta
#
# **Contestaron Todos**

# %%
data['NHCDP15'].count()
# Out:
# 24536

# %%
data['NHCDP15'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.05
# std          0.22
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          2.00
# Name: NHCDP15, dtype: object

# %%
data['NHCDP15'] = data.apply(lambda x: 0 if (x['NHCDP15'] == 2) else (1 if x['NHCDP15']==1 else 2), axis = 1)

# %%
data['NHCDP15'].value_counts()
# Out:
# 1    23292
# 0     1244
# Name: NHCDP15, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP15'].value_counts().index.tolist(),data['NHCDP15'].value_counts().tolist(), edgecolor = 'black', color = '#f1faee')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NHCDP15 \n ¿Este hogar tiene servicio de gas natural conectado a red pública?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP17
# ¿El servicio de gas natural lo pagan entre varios hogares de esta u otras viviendas?
#
# 0. No
# 1. Si
# 2. No Contesta
#
# **Contestan 22219**

# %%
data['NHCDP17'].count()
# Out:
# 22219

# %%
data['NHCDP17'].describe().apply("{0:.2f}".format)
# Out:
# count    22219.00
# mean         1.95
# std          0.22
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP17, dtype: object

# %%
data['NHCDP17'] = data.apply(lambda x: 0 if (x['NHCDP17'] == 2) else (1 if x['NHCDP17']==1 else 2), axis = 1)

# %%
data['NHCDP17'].value_counts()
# Out:
# 0    21095
# 2     2317
# 1     1124
# Name: NHCDP17, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP17'].value_counts().index.tolist(),data['NHCDP17'].value_counts().tolist(), edgecolor = 'k', color = '#cdb4db')
plt.xticks([0,1,2], ['No','Si','No Contesta'])
plt.title('Pregunta NHCDP17 \n ¿El servicio de gas natural lo pagan entre varios hogares de esta u otras viviendas?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP17A
# ¿Entre cuántos hogares? (gas natural)
#
# **Contestaron 1124**

# %%
data['NHCDP17A'].count()
# Out:
# 1124

# %%
data['NHCDP17A'].describe().apply("{0:.2f}".format)
# Out:
# count    1124.00
# mean        2.94
# std         1.78
# min         2.00
# 25%         2.00
# 50%         3.00
# 75%         3.00
# max        20.00
# Name: NHCDP17A, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP17A'], bins = np.arange(22)-0.5 , edgecolor = 'black', color = '#ffc8dd')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
plt.xticks(range(0,22,2))
#plt.bar_label(bars)
plt.title('NHCDP17A \n ¿Entre cuántos hogares? (gas natural)')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP17A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP17A"].mean()}')
plt.axvline(data['NHCDP17A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP17A"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP18
# ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de gas natural?
#
# **Contestaron 22219**

# %%
data['NHCDP18'].count()
# Out:
# 22219

# %%
data['NHCDP18'].describe().apply("{0:.2f}".format)
# Out:
# count     22219.00
# mean      46955.08
# std       45457.12
# min           0.00
# 25%       22000.00
# 50%       38000.00
# 75%       60000.00
# max      760000.00
# Name: NHCDP18, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP18'], bins = 50 , edgecolor = 'black', color = '#a2d2ff')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(9))
#plt.bar_label(bars)
plt.title('¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de gas natural?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP18'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP18"].mean()}')
plt.axvline(data['NHCDP18'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP18"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP18A
# ¿A cuántos meses correspondió el pago? (gas natural)
#
# **Contestaron 21523**

# %%
data['NHCDP18A'].count()
# Out:
# 21523

# %%
data['NHCDP18A'].describe().apply("{0:.2f}".format)
# Out:
# count    21523.00
# mean         1.00
# std          0.02
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          2.00
# Name: NHCDP18A, dtype: object

# %%
data['NHCDP18A'].value_counts()
# Out:
# 1.0    21515
# 2.0        8
# Name: NHCDP18A, dtype: int64

# %%
counts, edges, bars = plt.hist(data['NHCDP18A'], bins = np.arange(1,3.5)-0.5 , edgecolor = 'black', color = '#ffafcc')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
plt.xticks(range(3))
plt.bar_label(bars)
plt.title('NHCDP18A \n ¿A cuántos meses correspondió el pago? (gas natural)')
#plt.xlim([-1,10])
#plt.axvline(data['NHCDP18A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP18A"].mean()}')
#plt.axvline(data['NHCDP18A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP18A"].median()}')
#plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP19
# ¿El valor pagado incluyó consumo por negocios de industria, comercio o servicios? (gas natural)
#
# 0. No
# 1. Si
# 2. No contesta
#
# **Contestan 22219**

# %%
data['NHCDP19'].count()
# Out:
# 22219

# %%
data['NHCDP19'].describe().apply("{0:.2f}".format)
# Out:
# count    22219.00
# mean         1.99
# std          0.11
# min          1.00
# 25%          2.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP19, dtype: object

# %%
data['NHCDP19'] = data.apply(lambda x: 0 if (x['NHCDP19'] == 2) else (1 if x['NHCDP19']==1 else 2), axis = 1)

# %%
data['NHCDP19'].value_counts()
# Out:
# 0    21964
# 2     2317
# 1      255
# Name: NHCDP19, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP19'].value_counts().index.tolist(),data['NHCDP19'].value_counts().tolist(), edgecolor = 'k', color = '#264653')
plt.xticks([0,1,2], ['No','Si','No Contesta'])
plt.title('Pregunta NHCDP19 \n ¿El valor pagado incluyó consumo por negocios de industria, comercio o servicios? (gas natural)')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP24 PORTATIL
# ¿En este hogar tienen computador de escritorio (PC - Desktop) o portátil (laptop)?
#
# 0. No
# 1. Si
# 2. No Contesta
#
# **Todos Contestan**

# %%
data['NHCDP24'].count()
# Out:
# 24536

# %%
data['NHCDP24'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.20
# std          0.40
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          2.00
# Name: NHCDP24, dtype: object

# %%
data['NHCDP24'] = data.apply(lambda x: 0 if (x['NHCDP24'] == 2) else (1 if x['NHCDP24']==1 else 2), axis = 1)

# %%
data['NHCDP24'].value_counts()
# Out:
# 1    19507
# 0     5029
# Name: NHCDP24, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP24'].value_counts().index.tolist(),data['NHCDP24'].value_counts().tolist(), edgecolor = 'k', color = '#e9c46a')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NHCDP24 \n ¿En este hogar tienen computador de escritorio (PC - Desktop) o portátil (laptop)?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP24A
# ¿En este hogar tienen computador de escritorio (PC - Desktop) o portátil (laptop)?
# ¿Cuántos?
#
# **Contestan 19507**

# %%
data['NHCDP24A'].count()
# Out:
# 19507

# %%
data['NHCDP24A'].describe().apply("{0:.2f}".format)
# Out:
# count    19507.00
# mean         2.00
# std          1.10
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          3.00
# max          8.00
# Name: NHCDP24A, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP24A'], bins = np.arange(10)-0.5 , edgecolor = 'black', color = '#264653')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
plt.xticks(range(9))
#plt.bar_label(bars)
plt.title('Pregunta NHCDP24A \n ¿En este hogar tienen computador de escritorio (PC - Desktop) o portátil (laptop)? ¿Cuántos?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP24A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP24A"].mean()}')
plt.axvline(data['NHCDP24A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP24A"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP26
# ¿En este hogar tienen tabletas digitales (tablets)?
#
# 0. No
# 1. Sí
# 2. No Contesta
#
# **Todos Contestan**

# %%
data['NHCDP26'].count()
# Out:
# 24536

# %%
data['NHCDP26'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.73
# std          0.45
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP26, dtype: object

# %%
data['NHCDP26'] = data.apply(lambda x: 0 if (x['NHCDP26'] == 2) else (1 if x['NHCDP26']==1 else 2), axis = 1)

# %%
data['NHCDP26'].value_counts()
# Out:
# 0    17836
# 1     6700
# Name: NHCDP26, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP26'].value_counts().index.tolist(),data['NHCDP26'].value_counts().tolist(), edgecolor = 'k', color = '#f4a261')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NHCDP26 \n ¿En este hogar tienen tabletas digitales (tablets)?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP26A
# ¿En este hogar tienen tabletas digitales (tablets)?
# ¿Cuántas?
#
# **Contestan 6700**

# %%
data['NHCDP26A'].count()
# Out:
# 6700

# %%
data['NHCDP26A'].describe().apply("{0:.2f}".format)
# Out:
# count    6700.00
# mean        1.36
# std         0.64
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         2.00
# max        10.00
# Name: NHCDP26A, dtype: object

# %%
data['NHCDP26A'].value_counts()
# Out:
# 1.0     4781
# 2.0     1537
# 3.0      324
# 4.0       48
# 5.0        7
# 10.0       3
# Name: NHCDP26A, dtype: int64

# %%
counts, edges, bars = plt.hist(data['NHCDP26A'], bins = np.arange(12)-0.5 , edgecolor = 'black', color = '#e63946')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(3))
plt.bar_label(bars)
plt.title('NHCDP26A \n ¿En este hogar tienen tabletas digitales (tablets)? ¿Cuántas?')
#plt.xlim([-1,10])
#plt.axvline(data['NHCDP18A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP18A"].mean()}')
#plt.axvline(data['NHCDP18A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP18A"].median()}')
#plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP27 ***INTERNET***
# ¿El hogar tiene conexión a internet?
#
# 0. No
# 1. Si
# 2. No contesta
#
# **Todos Contestan**

# %%
data['NHCDP27'].count()
# Out:
# 24536

# %%
data['NHCDP27'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.09
# std          0.29
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          2.00
# Name: NHCDP27, dtype: object

# %%
data['NHCDP27'] = data.apply(lambda x: 0 if (x['NHCDP27'] == 2) else (1 if x['NHCDP27']==1 else 2), axis = 1)

# %%
data['NHCDP27'].value_counts()
# Out:
# 1    22281
# 0     2255
# Name: NHCDP27, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP27'].value_counts().index.tolist(),data['NHCDP27'].value_counts().tolist(), edgecolor = 'k', color = '#8ecae6')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NHCDP27 \n ¿El hogar tiene conexión a internet?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP27A
# ¿El hogar tiene conexión a internet Fijo?
#
# (la conexión solo puede realizarse en el interior o cercanía de la vivienda, e incluye conexión por WiFi)
#
# **Contestan los 22281**

# %%
data['NHCDP27A'].count()
# Out:
# 22281

# %%
data['NHCDP27A'].describe().apply("{0:.2f}".format)
# Out:
# count    22281.00
# mean         1.04
# std          0.20
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          2.00
# Name: NHCDP27A, dtype: object

# %%
data['NHCDP27A'] = data.apply(lambda x: 0 if (x['NHCDP27A'] == 2) else (1 if x['NHCDP27A']==1 else 2), axis = 1)

# %%
data['NHCDP27A'].value_counts()
# Out:
# 1    21339
# 2     2255
# 0      942
# Name: NHCDP27A, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP27A'].value_counts().index.tolist(),data['NHCDP27A'].value_counts().tolist(), edgecolor = 'k', color = '#3a5a40')
plt.xticks([0,1,2], ['No','Si','No contesta'])
plt.title('Pregunta NHCDP27A \n ¿El hogar tiene conexión a internet Fija?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP27B
# ¿El hogar tiene conexión a internet Movil?
#
# (conexión mediante red celular o modem inalámbrico o USB por cualquiera de los integrantes del hogar)
#
# **Contestan los 22281**

# %%
data['NHCDP27B'].count()
# Out:
# 22281

# %%
data['NHCDP27B'].describe().apply("{0:.2f}".format)
# Out:
# count    22281.00
# mean         1.52
# std          0.50
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP27B, dtype: object

# %%
data['NHCDP27B'] = data.apply(lambda x: 0 if (x['NHCDP27B'] == 2) else (1 if x['NHCDP27B']==1 else 2), axis = 1)

# %%
data['NHCDP27B'].value_counts()
# Out:
# 0    11623
# 1    10658
# 2     2255
# Name: NHCDP27B, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP27B'].value_counts().index.tolist(),data['NHCDP27B'].value_counts().tolist(), edgecolor = 'k', color = '#8ecae6')
plt.xticks([0,1,2], ['No','Si', 'No contesta'])
plt.title('Pregunta NHCDP27B \n ¿El hogar tiene conexión a internet movil?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP28
# Este hogar paga por el servicio de internet?
# 1. Sí
# 2. Sí, con el arriendo
# 3. No pagan
# 4. No contesta
#
# **Contestan los 22281**

# %%
data['NHCDP28'].count()
# Out:
# 22281

# %%
data['NHCDP28'].describe().apply("{0:.2f}".format)
# Out:
# count    22281.00
# mean         1.05
# std          0.29
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          3.00
# Name: NHCDP28, dtype: object

# %%
data['NHCDP28'] = data.apply(lambda x: 1 if (x['NHCDP28'] == 1) else (2 if x['NHCDP28'] == 2 else (3 if x['NHCDP28'] == 3 else 4)), axis = 1)

# %%
data['NHCDP28'].value_counts()
# Out:
# 1    21584
# 4     2255
# 3      425
# 2      272
# Name: NHCDP28, dtype: int64

# %%
plt.figure(figsize=(12,5))
bars = plt.bar(data['NHCDP28'].value_counts().index.tolist(),data['NHCDP28'].value_counts().tolist(), edgecolor = 'k', color = '#344e41')
plt.xticks([1,2,3,4], ['Si ','Si, con el arriendo', 'No pagan','No contesta'])
plt.title('Pregunta NHCDP28 \n ¿Este hogar paga por el servicio de internet?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP29
# ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de internet?
#
#
# **Contestan 21584**

# %%
data['NHCDP29'].count()
# Out:
# 21584

# %%
data['NHCDP29'].describe().apply("{0:.2f}".format)
# Out:
# count      21584.00
# mean       59256.43
# std        69023.12
# min            0.00
# 25%           98.00
# 50%        50000.00
# 75%        95000.00
# max      1500000.00
# Name: NHCDP29, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP29'], bins = 20 , edgecolor = 'black', color = '#023047')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
#plt.xticks(range(9))
#plt.bar_label(bars)
plt.title('Pregunta NHCDP29 \n ¿Cuánto pagó este hogar la ÚLTIMA VEZ por el servicio de internet?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP29'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP29"].mean()}')
plt.axvline(data['NHCDP29'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP29"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# ### NHCDP33
# ¿En el último mes pagó por el uso de alguna aplicación para ver películas, series, videos o escuchar música a través de internet?
#
# 0. No
# 1. Sí
# 2. No contesta
#
# **Todos Contestan**

# %%
data['NHCDP33'].count()
# Out:
# 24536

# %%
data['NHCDP33'].describe().apply("{0:.2f}".format)
# Out:
# count    24536.00
# mean         1.67
# std          0.47
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          2.00
# max          2.00
# Name: NHCDP33, dtype: object

# %%
data['NHCDP33'] = data.apply(lambda x: 0 if (x['NHCDP33'] == 2) else (1 if x['NHCDP33']==1 else 2), axis = 1)

# %%
data['NHCDP33'].value_counts()
# Out:
# 0    16411
# 1     8125
# Name: NHCDP33, dtype: int64

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(data['NHCDP33'].value_counts().index.tolist(),data['NHCDP33'].value_counts().tolist(), edgecolor = 'k', color = '#d5bdaf')
plt.xticks([0,1], ['No','Si'])
plt.title('Pregunta NHCDP33 \n ¿En el último mes pagó por el uso de alguna aplicación para ver películas, series, videos o escuchar música a través de internet?')
plt.bar_label(bars)
plt.grid(alpha = 0.2, axis = 'y')
plt.show()

# %% [markdown]
# #### NHCDP33A
# ¿Cuánto pagó este hogar por el uso de estas aplicaciones en el ÚLTIMO MES?
#
# **Contestan 8125**

# %%
data['NHCDP33A'].count()
# Out:
# 8125

# %%
data['NHCDP33A'].describe().apply("{0:.2f}".format)
# Out:
# count      8125.00
# mean      35826.50
# std       39903.90
# min          98.00
# 25%       19000.00
# 50%       30000.00
# 75%       40000.00
# max      950000.00
# Name: NHCDP33A, dtype: object

# %%
counts, edges, bars = plt.hist(data['NHCDP33A'], bins = 30 , edgecolor = 'black', color = '#6d6875')
#ticklabels = [i for i in range(5)]
#plt.xticks(range(5), ticklabels)
plt.xticks(np.linspace(0, data['NHCDP33A'].max(),6),rotation = 45)
#plt.bar_label(bars)
plt.title('Pregunta NHCDP33A \n ¿Cuánto pagó este hogar por el uso de estas aplicaciones en el ÚLTIMO MES?')
#plt.xlim([-1,10])
plt.axvline(data['NHCDP33A'].mean(), color='k', linestyle=':', linewidth=1, label = f'Media = {data["NHCDP33A"].mean()}')
plt.axvline(data['NHCDP33A'].median(), color='b', linestyle='dashed', linewidth=1, label = f'Mediana = {data["NHCDP33A"].median()}')
plt.legend()
plt.grid(alpha = 0.2, axis = 'y')
plt.show()
