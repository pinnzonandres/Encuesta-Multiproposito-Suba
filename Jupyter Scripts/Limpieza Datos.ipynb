# %%
import pandas as pd

# %%
data = pd.read_csv('..\Datos\EM2021_CSV.csv', sep = ',', encoding = 'latin-1')
# Out:
# C:\Users\wilson.pinzon\AppData\Local\Temp\ipykernel_9460\937974374.py:1: DtypeWarning: Columns (6,8,333) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('..\Datos\EM2021_CSV.csv', sep = ',', encoding = 'latin-1')

# %%
data.head()
# Out:
#    Unnamed: 0  DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0           1      166238    11  11001      3            2.0        Chapinero
# 1           2      166238    11  11001      3            2.0        Chapinero
# 2           3      220102    11  11001      3           19.0   Ciudad Bolívar
# 3           4      220102    11  11001      3           19.0   Ciudad Bolívar
# 4           5      220102    11  11001      3           19.0   Ciudad Bolívar
#
#    COD_UPZ_GRUPO NOMBRE_UPZ_GRUPO  ESTRATO2021  ... NHCMP12AUA23  \
# 0            NaN              NaN     11001202  ...          NaN
# 1            NaN              NaN     11001202  ...          NaN
# 2            NaN              NaN     11001219  ...          NaN
# 3            NaN              NaN     11001219  ...          NaN
# 4            NaN              NaN     11001219  ...          NaN
#
#    NHCMP12AUB23_1  NHCMP12AUB23_2  NHCMP12AUB23_3  NHCMP12AUB23_4  \
# ...

# %%
data.shape
# Out:
# (292281, 1547)

# %%
suba = data[data['NOMBRE_LOCALIDAD'] == 'Suba']

# %%
suba = suba.reset_index(drop = True)

# %%
suba.head()
# Out:
#    Unnamed: 0  DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0          12      222175    11  11001      1           11.0             Suba
# 1          13      222175    11  11001      1           11.0             Suba
# 2          14      222175    11  11001      1           11.0             Suba
# 3          15      222175    11  11001      1           11.0             Suba
# 4          16      222175    11  11001      1           11.0             Suba
#
#    COD_UPZ_GRUPO NOMBRE_UPZ_GRUPO  ESTRATO2021  ... NHCMP12AUA23  \
# 0           28.0        El Rincón     11001122  ...          NaN
# 1           28.0        El Rincón     11001122  ...          NaN
# 2           28.0        El Rincón     11001122  ...          NaN
# 3           28.0        El Rincón     11001122  ...          NaN
# 4           28.0        El Rincón     11001122  ...          NaN
#
#    NHCMP12AUB23_1  NHCMP12AUB23_2  NHCMP12AUB23_3  NHCMP12AUB23_4  \
# ...

# %%
suba['NOMBRE_UPZ_GRUPO'].value_counts()
# Out:
# Tibabuyes                                              2573
# Niza                                                   2414
# El Rincón                                              2382
# Suba                                                   2347
# El Prado                                               2328
# Casa Blanca Suba                                       2279
# La Floresta                                            2265
# Britalia                                               2252
# La Alhambra                                            2228
# SUBA: La Academia + Guaymaral + San José de Bavaria    2105
# Name: NOMBRE_UPZ_GRUPO, dtype: int64

# %%
#suba.to_excel('..\Datos\Encuesta_Multiproposito_Suba.xlsx', index = False)
suba.to_csv('..\Datos\Encuesta_Multiproposito_Suba.csv', index = False)

# %% [markdown]
# ## Añadir Diccionario de variables para seleccionar las preguntas

# %%
dicc = pd.read_excel('..\Datos\diccionario_propio.xlsx')

# %%
dicc.head()
# Out:
#     NOMBRE TABLA NOMBRE COLUMNA                      TEXTO_PREGUNTA  \
# 0  DBF_MTP_256_1     DIRECTORIO  Identificador numérico de vivienda
# 1  DBF_MTP_256_1           DPTO                     1. Departamento
# 2  DBF_MTP_256_1           MPIO                        2. Municipio
# 3  DBF_MTP_256_1          CLASE                               clase
# 4  DBF_MTP_256_1  COD_LOCALIDAD              Código de la localidad
#
#                            DESCRIPCIÓN_VALORES_LISTA   TIPO   TAMAÑO  ID
# 0                                                NaN  NUMBER       8   0
# 1                                         DPTOIDDPTO  NUMBER       4   0
# 2                                         MUNIIDMUNI  NUMBER       5   0
# 3  1 Cabecera\n2 Centros poblados\n3 Área rural d...  NUMBER       8   0
# 4                                                NaN  NUMBER       8   1

# %%
dicc = dicc[dicc['ID'] == 1]

# %%
lista_dic = list(dicc['NOMBRE COLUMNA'].values)
lista_dic.remove('NPCHP36a')

# %% [markdown]
# ### Nos quedamos con las columnas con las preguntas que nos interesan

# %%
suba_c = suba[lista_dic]

# %%
for i in lista_dic:
    if i not in list(suba.columns):
        print(i)

# %%
suba_c
# Out:
#        COD_LOCALIDAD NOMBRE_LOCALIDAD  COD_UPZ_GRUPO  \
# 0               11.0             Suba           28.0
# 1               11.0             Suba           28.0
# 2               11.0             Suba           28.0
# 3               11.0             Suba           28.0
# 4               11.0             Suba           28.0
# ...              ...              ...            ...
# 24531           11.0             Suba          806.0
# 24532           11.0             Suba          806.0
# 24533           11.0             Suba           18.0
# 24534           11.0             Suba           71.0
# 24535           11.0             Suba            NaN
#
#                                         NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0                                              El Rincón     11001122
# 1                                              El Rincón     11001122
# 2                                              El Rincón     11001122
# ...

# %%
suba_c.describe()
# Out:
#        COD_LOCALIDAD  COD_UPZ_GRUPO   ESTRATO2021        NVCBP1       NVCBP2  \
# count        24536.0   23173.000000  2.453600e+04  24536.000000  22835.00000
# mean            11.0      99.498727  1.100115e+07      3.159235      1.14215
# std              0.0     223.847243  3.356643e+01      1.068032      0.40647
# min             11.0      18.000000  1.100111e+07      1.000000      1.00000
# 25%             11.0      20.000000  1.100112e+07      2.000000      1.00000
# 50%             11.0      25.000000  1.100116e+07      4.000000      1.00000
# 75%             11.0      28.000000  1.100118e+07      4.000000      1.00000
# max             11.0     806.000000  1.100121e+07      4.000000      3.00000
#
#              NVCBP3        NVCBP4        NVCBP5        NVCBP6        NVCBP7  \
# count  24536.000000  24536.000000  24536.000000  24536.000000  12772.000000
# mean       1.105274      1.367216      1.140773      5.335915      1.432978
# ...

# %%
suba_c.shape
# Out:
# (24536, 419)

# %%
suba_c.to_csv('Encuesta_Suba_Filtrado_Preguntas.csv', index = False)

# %% [markdown]
# ### Exploración de Datos
